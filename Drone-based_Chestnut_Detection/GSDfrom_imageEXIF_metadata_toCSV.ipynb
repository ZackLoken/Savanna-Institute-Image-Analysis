# %% [markdown]
# ### <center> Calculating GSD from UAV image EXIF data using [PyExifTool](https://pypi.org/project/PyExifTool/) </center>
# ##### Requires Phil Harvey's [ExifTool](https://exiftool.org/) be installed and on system PATH

# %%
import os
import subprocess
import exiftool
import pandas as pd

# Check if ExifTool is accessible
try:
    subprocess.run(["exiftool", "-ver"], check=True)
    print("ExifTool is accessible.")
except subprocess.CalledProcessError:
    print("ExifTool is not accessible.")
print()

def GSD_from_exif_batch(folder):
    """
    Calculate ground sampling distance (GSD) in cm/pixel from Exif data for all images in folder
    :param folder: path to folder containing images
    :return: csv file containing Exif data and GSD for all images in folder
    """
    # Get list of .JPG,.PNG, or .TIF files in folder
    files = [file for file in os.listdir(folder) if file.endswith((".JPG", ".PNG", ".TIF"))]

    # Add folder path to each file and store as string in quotations
    files = [os.path.join(folder, file) for file in files]

    # Print all tags for first file in folder
    with exiftool.ExifToolHelper() as et:
        for d in et.get_metadata(files[0]):
            for k, v in d.items():
                print(f"{k} = {v}")
    print()

    # Empty list for storing Exif data
    Exif_data = []

    # Values for calculating ground sampling distance (GSD) W,H in cm/pixel are: SensorWidth (mm),
    # SensorHeight (mm), RelativeAltitude (m), FocalLength (mm), ImageWidth (px), ImageHeight (px)

    # Store specified tags as list of dictionaries for all files in folder
    with exiftool.ExifToolHelper() as et:
        for d in et.get_tags(files[0:-1], tags=["SourceFile", "FileName", "ImageWidth", "ImageHeight", # specify tags here
                                                "FocalLength", "RelativeAltitude", "GimbalRollDegree", "GimbalYawDegree",
                                                "GimbalPitchDegree", "FlightRollDegree", "FlightYawDegree", "FlightPitchDegree",
                                                "XMP:GPSLatitude", "XMP:GPSLongitude"]):
            # append d to Exif_data list
            Exif_data.append(d)

    # Exif_data is a list of dictionaries. Convert to pandas dataframe where each unique value for SourceFile is a row
    df = pd.DataFrame(Exif_data)

    # Clean up column names; remove the text before the colon
    df.columns = df.columns.str.split(":").str[-1]

    # remove plus sign from RelativeAltitude
    df["RelativeAltitude"] = df["RelativeAltitude"].str.replace("+", "")

    # Convert columns to float
    df["RelativeAltitude"] = df["RelativeAltitude"].astype(float)
    df["FocalLength"] = df["FocalLength"].astype(float)
    df["ImageWidth"] = df["ImageWidth"].astype(float)
    df["ImageHeight"] = df["ImageHeight"].astype(float)

    # Add sensor width to dataframe (UAV is DJI Mavic 3M)
    # https://sdk-forum.dji.net/hc/en-us/articles/12325496609689-What-is-the-custom-camera-parameters-for-Mavic-3-Enterprise-series-and-Mavic-3M-
    df["SensorWidth"] = 17.4

    # Add GSDw and to dataframe
    # GSDw (at nadir) = (SensorWidth * RelativeHeight * 100) / (FocalLength * ImageWidth)
    df["GSDw"] = (df.SensorWidth * df.RelativeAltitude * 100) / (df.FocalLength * df.ImageWidth)

    # Save dataframe to csv
    df.to_csv(os.path.join(folder, f"Exif_data_{df['GSDw'].mean():.2f}.csv"), index=False) # save mean GSDw in filename

    return df
# Out:
# ExifTool is accessible.

# %%
# Define paths to folders containing images
folders = ["S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230823_Route9-Orchard1perp_0.39GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard1perp_0.84GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard2_0.86GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard3-closePar_RGB_0.67GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231046_004_Route9Orchard1South_0.75GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231102_005_Route9Orchard1North_1.60GSD/"]

# Call function for each folder in folders
for folder in folders:
    GSD_from_exif_batch(folder) # saves csv file with GSD in folder

# %%
# load csv "S:\Zack\Imagery\Chestnut\Best_FlightParameters\best_images.csv" as pd dataframe
df = pd.read_csv("S:/Zack/Imagery/Chestnut/Best_FlightParameters/best_images.csv")

# df.set_index("Tree ID", inplace=True)

# %%
dir = "S:/Zack/Imagery/Chestnut/Best_FlightParameters/"

# create folder in dir called bestImages_PNGs
if not os.path.exists(os.path.join(dir, "bestImages_PNGs")):
    os.makedirs(os.path.join(dir, "bestImages_PNGs"))

# %%
# import shutil

# for treeID in df['Tree ID']:
#     # copy image from source to destination
#     src = f"S:/Zack/Imagery/Chestnut/Individual_Tree_Trunks/Route9/Route9_Orchard3_DawsonLab/easyIDP/Roboflow/images/{treeID}.png"
#     dst = f"S:/Zack/Imagery/Chestnut/Best_FlightParameters/bestImages_PNGs/{treeID}.png"
#     shutil.copy(src, dst)

# %%
# create folder in dir called bestImages_raw
if not os.path.exists(os.path.join(dir, "bestImages_raw")):
    os.makedirs(os.path.join(dir, "bestImages_raw"))

# %%
# make list of treeIDs in bestImages_PNGs folder
treeIDs = [file.split(".")[0] for file in os.listdir(os.path.join(dir, "bestImages_PNGs"))]

# %%
import shutil

# for each image in bestImages_PNGs folder, copy the corresponding raw image to bestImages_raw folder. 
# use df to get path of raw image, and copy from path to bestImages_raw folder
for treeID in treeIDs:
    # get path of raw image
    raw = df.loc[int(treeID), "Best UAV Image Path"]
    # copy path to bestImages_raw folder
    shutil.copy(raw, os.path.join(dir, "bestImages_raw"))

# %%
best_image_folder = "S:/Zack/Imagery/Chestnut/Best_FlightParameters/bestImages_raw/"

# %%
exif_df = GSD_from_exif_batch(best_image_folder)
# Out:
# SourceFile = S:/Zack/Imagery/Chestnut/Best_FlightParameters/bestImages_raw/DJI_20230823123355_0083_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230823123355_0083_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Best_FlightParameters/bestImages_raw
# File:FileSize = 10399744
# File:FileModifyDate = 2024:04:15 12:06:52-05:00
# File:FileAccessDate = 2024:04:15 12:07:00-05:00
# File:FileCreateDate = 2024:04:15 12:06:52-05:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:23 12:33:55
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.001
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 4
# EXIF:ISO = 160
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:23 12:33:55
# EXIF:CreateDate = 2023:08:23 12:33:55
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.000999989107017163
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 2
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.5000298333333
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.01928025
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 416.554
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 35078
# EXIF:ThumbnailImage = (Binary data 35078 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:23 12:33:55-05:00
# XMP:CreateDate = 2023:08:23 12:33:55-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.500029860
# XMP:GPSLongitude = -81.019280254
# XMP:AbsoluteAltitude = +416.554
# XMP:RelativeAltitude = +34.841
# XMP:GimbalRollDegree = +180.00
# XMP:GimbalYawDegree = +0.10
# XMP:GimbalPitchDegree = -90.0
# XMP:FlightRollDegree = +1.60
# XMP:FlightYawDegree = -179.9
# XMP:FlightPitchDegree = -3.8
# XMP:FlightXSpeed = -5.4
# XMP:FlightYSpeed = 0.0
# XMP:FlightZSpeed = 0.2
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.00938
# XMP:RtkStdLat = 0.01136
# XMP:RtkStdHgt = 0.0189
# XMP:RtkDiffAge = 1.0
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:23 17:34:10.809987
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 51290
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = 1739fac254174aefb315230655d44805
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 1153051
# MPF:MPImageStart = 9244672
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 1153051 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.001
# Composite:GPSAltitude = 416.554
# Composite:GPSLatitude = 40.5000298333333
# Composite:GPSLongitude = -81.01928025
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.5000298333333 -81.01928025
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 12.2585660338899

# %%
# change Best UAV Image Path in df to image name. 
df["Best UAV Image Path"] = df["Best UAV Image Path"].str.split("/").str[-1]

# %%
# change column name to "image Name"
df.rename(columns={"Best UAV Image Path": "Image Name"}, inplace=True)

# %%
# if df['Image Name'] in exif_df['FileName'], then join the two dataframes using the Image Name as the key
df_merged = pd.merge(df, exif_df, left_on="Image Name", right_on="FileName")

# %%
# remove duplicate rows
df_merged.drop_duplicates(inplace=True)

# %%
# subtract 1 from tree ID
df_merged["Tree ID"] = df_merged["Tree ID"] - 1

# %%
print(df_merged)
# Out:
#     Tree ID                     Image Name  \
# 0        14  DJI_20230823131758_0620_D.JPG
# 1        28  DJI_20230823131045_0338_D.JPG
# 2        32  DJI_20230823125646_0967_D.JPG
# 3        33  DJI_20230823132018_0713_D.JPG
# 4        35  DJI_20230823125647_0968_D.JPG
# ..      ...                            ...
# 93      393  DJI_20230823123539_0152_D.JPG
# 94      406  DJI_20230823124307_0447_D.JPG
# 95      407  DJI_20230823124047_0354_D.JPG
# 96      408  DJI_20230823130933_0291_D.JPG
# 97      410  DJI_20230823130742_0219_D.JPG
#
#                                            SourceFile  \
# 0   S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 1   S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 2   S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 3   S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 4   S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# ..                                                ...
# 93  S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 94  S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 95  S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 96  S:/Zack/Imagery/Chestnut/Best_FlightParameters...
# 97  S:/Zack/Imagery/Chestnut/Best_FlightParameters...
#
#                          FileName  ImageWidth  ImageHeight  FocalLength  \
# 0   DJI_20230823131758_0620_D.JPG      5280.0       3956.0        12.29
# 1   DJI_20230823131045_0338_D.JPG      5280.0       3956.0        12.29
# 2   DJI_20230823125646_0967_D.JPG      5280.0       3956.0        12.29
# 3   DJI_20230823132018_0713_D.JPG      5280.0       3956.0        12.29
# 4   DJI_20230823125647_0968_D.JPG      5280.0       3956.0        12.29
# ..                            ...         ...          ...          ...
# 93  DJI_20230823123539_0152_D.JPG      5280.0       3956.0        12.29
# 94  DJI_20230823124307_0447_D.JPG      5280.0       3956.0        12.29
# 95  DJI_20230823124047_0354_D.JPG      5280.0       3956.0        12.29
# 96  DJI_20230823130933_0291_D.JPG      5280.0       3956.0        12.29
# 97  DJI_20230823130742_0219_D.JPG      5280.0       3956.0        12.29
#
#     RelativeAltitude GimbalRollDegree GimbalYawDegree  GimbalPitchDegree  \
# 0             43.189            +0.00           -90.0              -75.0
# 1             32.645            +0.00          +89.90              -75.0
# 2             28.081            +0.00          -179.9              -89.9
# 3             47.602            +0.00           -90.0              -74.9
# 4             29.664            +0.00          -179.9              -89.9
# ..               ...              ...             ...                ...
# 93            36.420          +180.00          -179.9              -90.0
# 94            40.970            +0.00          -179.9              -89.9
# 95            42.251            +0.00          -179.9              -89.9
# 96            48.001            +0.00           -90.1              -74.9
# 97            47.210            +0.00           -90.0              -75.0
#
#    FlightRollDegree FlightYawDegree FlightPitchDegree    GPSLatitude  \
# 0              -0.3           -90.0              -1.7  +40.499339575
# 1             +1.40          +90.10              -2.3  +40.499809111
# 2             +0.00         +180.00              -5.2  +40.499495004
# 3              -0.8           -90.0              -0.8  +40.499151549
# 4              -0.5         +180.00              -5.7  +40.499420811
# ..              ...             ...               ...            ...
# 93             -2.8           +0.00              -0.6  +40.500384662
# 94            +2.40         +180.00              -5.7  +40.497998064
# 95            +3.30         +179.90              -4.3  +40.498664080
# 96             -3.7           -90.0              -3.3  +40.499903491
# 97             -3.6           -89.8              -7.5  +40.500090702
#
#     GPSLongitude  SensorWidth      GSDw
# 0     -81.023336         17.4  1.158075
# 1     -81.023082         17.4  0.875347
# 2     -81.022984         17.4  0.752967
# 3     -81.023103         17.4  1.276405
# 4     -81.022984         17.4  0.795414
# ..           ...          ...       ...
# 93    -81.019404         17.4  0.976570
# 94    -81.020268         17.4  1.098574
# 95    -81.020020         17.4  1.132923
# 96    -81.019891         17.4  1.287104
# 97    -81.019415         17.4  1.265894
#
# [98 rows x 18 columns]

# %%
# save df_merged to csv in dir
df_merged.to_csv(os.path.join(dir, "best_flightParameters.csv"), index=False) # save mean GSDw in filename
