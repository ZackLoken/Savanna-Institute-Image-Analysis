# %% [markdown]
# ### <center> Calculating GSD from UAV image EXIF data using [PyExifTool](https://pypi.org/project/PyExifTool/) </center>
# ##### Requires Phil Harvey's [ExifTool](https://exiftool.org/) be installed and on system PATH

# %%
import os
import subprocess
import exiftool
import pandas as pd

# Check if ExifTool is accessible
try:
    subprocess.run(["exiftool", "-ver"], check=True)
    print("ExifTool is accessible.")
except subprocess.CalledProcessError:
    print("ExifTool is not accessible.")
print()

def GSD_from_exif_batch(folder):
    """
    Calculate ground sampling distance (GSD) in cm/pixel from Exif data for all images in folder
    :param folder: path to folder containing images
    :return: csv file containing Exif data and GSD for all images in folder
    """
    # Get list of .JPG,.PNG, or .TIF files in folder
    files = [file for file in os.listdir(folder) if file.endswith((".JPG", ".PNG", ".TIF"))]

    # Add folder path to each file and store as string in quotations
    files = [os.path.join(folder, file) for file in files]

    # Print all tags for first file in folder
    with exiftool.ExifToolHelper() as et:
        for d in et.get_metadata(files[0]):
            for k, v in d.items():
                print(f"{k} = {v}")
    print()

    # Empty list for storing Exif data
    Exif_data = []

    # Values for calculating ground sampling distance (GSD) W,H in cm/pixel are: SensorWidth (mm),
    # SensorHeight (mm), RelativeAltitude (m), FocalLength (mm), ImageWidth (px), ImageHeight (px)

    # Store specified tags as list of dictionaries for all files in folder
    with exiftool.ExifToolHelper() as et:
        for d in et.get_tags(files[0:-1], tags=["SourceFile", "FileName", "ImageWidth", "ImageHeight", # specify tags here
                                                "FocalLength", "RelativeAltitude"]):
            # append d to Exif_data list
            Exif_data.append(d)

    # Exif_data is a list of dictionaries. Convert to pandas dataframe where each unique value for SourceFile is a row
    df = pd.DataFrame(Exif_data)

    # Clean up column names; remove the text before the colon
    df.columns = df.columns.str.split(":").str[-1]

    # remove plus sign from RelativeAltitude
    df["RelativeAltitude"] = df["RelativeAltitude"].str.replace("+", "")

    # Convert columns to float
    df["RelativeAltitude"] = df["RelativeAltitude"].astype(float)
    df["FocalLength"] = df["FocalLength"].astype(float)
    df["ImageWidth"] = df["ImageWidth"].astype(float)
    df["ImageHeight"] = df["ImageHeight"].astype(float)

    # Add sensor width to dataframe (UAV is DJI Mavic 3M)
    # https://sdk-forum.dji.net/hc/en-us/articles/12325496609689-What-is-the-custom-camera-parameters-for-Mavic-3-Enterprise-series-and-Mavic-3M-
    df["SensorWidth"] = 17.4

    # Add GSDw and to dataframe
    # GSDw = (SensorWidth * RelativeHeight * 100) / (FocalLength * ImageWidth)
    df["GSDw"] = (df.SensorWidth * df.RelativeAltitude * 100) / (df.FocalLength * df.ImageWidth)

    # Save dataframe to csv
    df.to_csv(os.path.join(folder, f"Exif_data_{df['GSDw'].mean():.2f}.csv"), index=False) # save mean GSDw in filename
# Out:
# ExifTool is accessible.

# %%
# Define paths to folders containing images
folders = ["S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230823_Route9-Orchard1perp_0.39GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard1perp_0.84GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard2_0.86GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard3-closePar_RGB_0.67GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231046_004_Route9Orchard1South_0.75GSD/",
           "S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231102_005_Route9Orchard1North_1.60GSD/"]

# Call function for each folder in folders
for folder in folders:
    GSD_from_exif_batch(folder) # saves csv file with GSD in folder
# Out:
# SourceFile = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230823_Route9-Orchard1perp_0.39GSD/DJI_20230823095837_0001_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230823095837_0001_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230823_Route9-Orchard1perp_0.39GSD
# File:FileSize = 9195520
# File:FileModifyDate = 2023:08:23 09:58:40-05:00
# File:FileAccessDate = 2023:12:08 10:02:10-06:00
# File:FileCreateDate = 2023:12:04 14:58:10-06:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:23 09:58:37
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.001
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 4
# EXIF:ISO = 120
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:23 09:58:37
# EXIF:CreateDate = 2023:08:23 09:58:37
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.000999989107017163
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 10
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.5050681944444
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.0333841666667
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 436.263
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 29792
# EXIF:ThumbnailImage = (Binary data 29792 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:23 09:58:37-05:00
# XMP:CreateDate = 2023:08:23 09:58:37-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.505068216
# XMP:GPSLongitude = -81.033384167
# XMP:AbsoluteAltitude = +436.263
# XMP:RelativeAltitude = +35.514
# XMP:GimbalRollDegree = +0.00
# XMP:GimbalYawDegree = +88.90
# XMP:GimbalPitchDegree = -75.0
# XMP:FlightRollDegree = +1.60
# XMP:FlightYawDegree = +89.80
# XMP:FlightPitchDegree = +15.50
# XMP:FlightXSpeed = -0.1
# XMP:FlightYSpeed = 3.8
# XMP:FlightZSpeed = 0.3
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.00978
# XMP:RtkStdLat = 0.01172
# XMP:RtkStdHgt = 0.02141
# XMP:RtkDiffAge = 1.2
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:23 14:58:52.953425
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 47526
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = 76c45234da1f47de836bc22b628d1de9
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 993033
# MPF:MPImageStart = 8200192
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 993033 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.001
# Composite:GPSAltitude = 436.263
# Composite:GPSLatitude = 40.5050681944444
# Composite:GPSLongitude = -81.0333841666667
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.5050681944444 -81.0333841666667
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 12.6736035331688
#
# SourceFile = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard1perp_0.84GSD/DJI_20230824094637_0001_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230824094637_0001_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard1perp_0.84GSD
# File:FileSize = 8486912
# File:FileModifyDate = 2023:08:24 09:46:40-05:00
# File:FileAccessDate = 2023:12:08 10:02:18-06:00
# File:FileCreateDate = 2023:12:04 14:43:11-06:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:24 09:46:37
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.004
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 2
# EXIF:ISO = 160
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:24 09:46:37
# EXIF:CreateDate = 2023:08:24 09:46:37
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.00399995642806865
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 1
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.5024531666667
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.0285994444444
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 423.947
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 32320
# EXIF:ThumbnailImage = (Binary data 32320 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:24 09:46:37-05:00
# XMP:CreateDate = 2023:08:24 09:46:37-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.502453181
# XMP:GPSLongitude = -81.028599456
# XMP:AbsoluteAltitude = +423.947
# XMP:RelativeAltitude = +23.134
# XMP:GimbalRollDegree = -0.4
# XMP:GimbalYawDegree = +92.00
# XMP:GimbalPitchDegree = -74.9
# XMP:FlightRollDegree = +6.00
# XMP:FlightYawDegree = +97.30
# XMP:FlightPitchDegree = +3.20
# XMP:FlightXSpeed = 0.0
# XMP:FlightYSpeed = 0.0
# XMP:FlightZSpeed = 0.0
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.00948
# XMP:RtkStdLat = 0.01112
# XMP:RtkStdHgt = 0.02083
# XMP:RtkDiffAge = 2.0
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:24 14:46:53.604935
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 55456
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = ca764f04e1ed4866b3cf426ae9ad32cf
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 1049325
# MPF:MPImageStart = 7434240
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 1049325 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.004
# Composite:GPSAltitude = 423.947
# Composite:GPSLatitude = 40.5024531666667
# Composite:GPSLongitude = -81.0285994444444
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.5024531666667 -81.0285994444444
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 10.2585660338899
#
# SourceFile = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard2_0.86GSD/DJI_20230824084645_0001_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230824084645_0001_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard2_0.86GSD
# File:FileSize = 7065600
# File:FileModifyDate = 2023:08:24 08:46:48-05:00
# File:FileAccessDate = 2023:12:08 10:06:07-06:00
# File:FileCreateDate = 2023:12:04 15:26:10-06:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:24 08:46:45
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.004
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 2
# EXIF:ISO = 110
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:24 08:46:45
# EXIF:CreateDate = 2023:08:24 08:46:45
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.00399995642806865
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 1
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.5012651944444
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.0308463055556
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 437.015
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 26324
# EXIF:ThumbnailImage = (Binary data 26324 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:24 08:46:45-05:00
# XMP:CreateDate = 2023:08:24 08:46:45-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.501265217
# XMP:GPSLongitude = -81.030846308
# XMP:AbsoluteAltitude = +437.015
# XMP:RelativeAltitude = +36.212
# XMP:GimbalRollDegree = +0.00
# XMP:GimbalYawDegree = +148.70
# XMP:GimbalPitchDegree = -89.9
# XMP:FlightRollDegree = +4.70
# XMP:FlightYawDegree = +154.40
# XMP:FlightPitchDegree = -0.8
# XMP:FlightXSpeed = 0.0
# XMP:FlightYSpeed = 0.0
# XMP:FlightZSpeed = 0.0
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.00995
# XMP:RtkStdLat = 0.0125
# XMP:RtkStdHgt = 0.02098
# XMP:RtkDiffAge = 2.4
# XMP:NTRIPMountPoint = REACH
# XMP:NTRIPPort = 2101
# XMP:NTRIPHost = 192.168.42.1
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:24 13:47:01.949801
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 53353
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = f5afe6c30ec84004808c8f609afb6ebe
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 845701
# MPF:MPImageStart = 6217728
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 845701 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.004
# Composite:GPSAltitude = 437.015
# Composite:GPSLatitude = 40.5012651944444
# Composite:GPSLongitude = -81.0308463055556
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.5012651944444 -81.0308463055556
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 10.7991344152526
#
# SourceFile = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard3-closePar_RGB_0.67GSD/DJI_20230824131252_0001_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230824131252_0001_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/20230824_Route9-Orchard3-closePar_RGB_0.67GSD
# File:FileSize = 9764864
# File:FileModifyDate = 2023:08:24 13:12:54-05:00
# File:FileAccessDate = 2023:12:08 10:05:02-06:00
# File:FileCreateDate = 2023:12:04 15:42:42-06:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:24 13:12:52
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.002
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 2
# EXIF:ISO = 100
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:24 13:12:52
# EXIF:CreateDate = 2023:08:24 13:12:52
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.00199997821403433
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 1
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.497591
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.0225585555556
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 374.232
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 31214
# EXIF:ThumbnailImage = (Binary data 31214 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:24 13:12:52-05:00
# XMP:CreateDate = 2023:08:24 13:12:52-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.497591018
# XMP:GPSLongitude = -81.022558572
# XMP:AbsoluteAltitude = +374.232
# XMP:RelativeAltitude = +18.669
# XMP:GimbalRollDegree = +180.00
# XMP:GimbalYawDegree = -65.5
# XMP:GimbalPitchDegree = -90.0
# XMP:FlightRollDegree = +0.90
# XMP:FlightYawDegree = +109.70
# XMP:FlightPitchDegree = +2.40
# XMP:FlightXSpeed = 0.2
# XMP:FlightYSpeed = 0.0
# XMP:FlightZSpeed = 0.0
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.00991
# XMP:RtkStdLat = 0.01008
# XMP:RtkStdHgt = 0.0191
# XMP:RtkDiffAge = 17.2
# XMP:NTRIPMountPoint = REACH
# XMP:NTRIPPort = 2101
# XMP:NTRIPHost = 192.168.42.1
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:24 18:13:12.862867
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 58999
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = e6816086e4cd4653a62bea27ede94435
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 1065466
# MPF:MPImageStart = 8695808
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 1065466 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.002
# Composite:GPSAltitude = 374.232
# Composite:GPSLatitude = 40.497591
# Composite:GPSLongitude = -81.0225585555556
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.497591 -81.0225585555556
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 11.9366379390026
#
# SourceFile = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231046_004_Route9Orchard1South_0.75GSD/DJI_20230823104802_0001_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230823104802_0001_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231046_004_Route9Orchard1South_0.75GSD
# File:FileSize = 10911744
# File:FileModifyDate = 2023:08:23 10:48:04-05:00
# File:FileAccessDate = 2023:12:08 10:04:51-06:00
# File:FileCreateDate = 2023:12:04 15:01:42-06:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:23 10:48:02
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.001
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 4
# EXIF:ISO = 360
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:23 10:48:02
# EXIF:CreateDate = 2023:08:23 10:48:02
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.000999989107017163
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 1
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.5027858333333
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.0285722777778
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 435.333
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 34926
# EXIF:ThumbnailImage = (Binary data 34926 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:23 10:48:02-05:00
# XMP:CreateDate = 2023:08:23 10:48:02-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.502785846
# XMP:GPSLongitude = -81.028572304
# XMP:AbsoluteAltitude = +435.333
# XMP:RelativeAltitude = +36.112
# XMP:GimbalRollDegree = +0.00
# XMP:GimbalYawDegree = +79.60
# XMP:GimbalPitchDegree = -89.9
# XMP:FlightRollDegree = +7.20
# XMP:FlightYawDegree = +85.20
# XMP:FlightPitchDegree = +5.50
# XMP:FlightXSpeed = 0.0
# XMP:FlightYSpeed = 0.0
# XMP:FlightZSpeed = 0.0
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.01065
# XMP:RtkStdLat = 0.01204
# XMP:RtkStdHgt = 0.02271
# XMP:RtkDiffAge = 2.2
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:23 15:48:17.997934
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 48530
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = d3e1da27689c4750b4353813330fd75b
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 1115336
# MPF:MPImageStart = 9793536
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 1115336 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.001
# Composite:GPSAltitude = 435.333
# Composite:GPSLatitude = 40.5027858333333
# Composite:GPSLongitude = -81.0285722777778
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.5027858333333 -81.0285722777778
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 11.0886410324476
#
# SourceFile = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231102_005_Route9Orchard1North_1.60GSD/DJI_20230823110453_0003_D.JPG
# ExifTool:ExifToolVersion = 12.7
# File:FileName = DJI_20230823110453_0003_D.JPG
# File:Directory = S:/Zack/Imagery/Chestnut/Annotation/Ohio/Route9/DJI_202308231102_005_Route9Orchard1North_1.60GSD
# File:FileSize = 10342400
# File:FileModifyDate = 2023:08:23 11:04:54-05:00
# File:FileAccessDate = 2023:12:08 10:03:15-06:00
# File:FileCreateDate = 2023:12:04 15:04:10-06:00
# File:FilePermissions = 100666
# File:FileType = JPEG
# File:FileTypeExtension = JPG
# File:MIMEType = image/jpeg
# File:ExifByteOrder = II
# File:ImageWidth = 5280
# File:ImageHeight = 3956
# File:EncodingProcess = 0
# File:BitsPerSample = 8
# File:ColorComponents = 3
# File:YCbCrSubSampling = 2 2
# EXIF:ImageDescription = default
# EXIF:Make = DJI
# EXIF:Model = M3M
# EXIF:Orientation = 1
# EXIF:XResolution = 72
# EXIF:YResolution = 72
# EXIF:ResolutionUnit = 2
# EXIF:Software = 10.12.05.45
# EXIF:ModifyDate = 2023:08:23 11:04:53
# EXIF:YCbCrPositioning = 2
# EXIF:ExposureTime = 0.001
# EXIF:FNumber = 2.8
# EXIF:ExposureProgram = 4
# EXIF:ISO = 250
# EXIF:SensitivityType = 2
# EXIF:ExifVersion = 0230
# EXIF:DateTimeOriginal = 2023:08:23 11:04:53
# EXIF:CreateDate = 2023:08:23 11:04:53
# EXIF:ComponentsConfiguration = 1 2 3 0
# EXIF:ShutterSpeedValue = 0.000999989107017163
# EXIF:ApertureValue = 2.79917173119039
# EXIF:ExposureCompensation = 0
# EXIF:MaxApertureValue = 2.79917173119039
# EXIF:SubjectDistance = 0
# EXIF:MeteringMode = 1
# EXIF:LightSource = 10
# EXIF:Flash = 0
# EXIF:FocalLength = 12.29
# EXIF:MakerNoteUnknownText = DJI MakerNotes
# EXIF:FlashpixVersion = 0100
# EXIF:ColorSpace = 1
# EXIF:ExifImageWidth = 5280
# EXIF:ExifImageHeight = 3956
# EXIF:InteropIndex = R98
# EXIF:InteropVersion = 0100
# EXIF:FileSource = 3
# EXIF:SceneType = 1
# EXIF:CustomRendered = 0
# EXIF:ExposureMode = 0
# EXIF:WhiteBalance = 0
# EXIF:DigitalZoomRatio = 1
# EXIF:FocalLengthIn35mmFormat = 24
# EXIF:SceneCaptureType = 0
# EXIF:GainControl = 0
# EXIF:Contrast = 0
# EXIF:Saturation = 0
# EXIF:Sharpness = 0
# EXIF:DeviceSettingDescription = (Binary data 4 bytes, use -b option to extract)
# EXIF:SerialNumber = 1581F5FKD231300C1FFQ
# EXIF:LensInfo = 0.24 0.24 2.8 11
# EXIF:GPSVersionID = 2 3 0 0
# EXIF:GPSLatitudeRef = N
# EXIF:GPSLatitude = 40.5043238055556
# EXIF:GPSLongitudeRef = W
# EXIF:GPSLongitude = 81.0293911666667
# EXIF:GPSAltitudeRef = 0
# EXIF:GPSAltitude = 436.264
# EXIF:GPSStatus = A
# EXIF:GPSMapDatum = WGS-84
# EXIF:XPComment = 0.9.142
# EXIF:XPKeywords = single
# EXIF:Compression = 7
# EXIF:ThumbnailOffset = 1350
# EXIF:ThumbnailLength = 34303
# EXIF:ThumbnailImage = (Binary data 34303 bytes, use -b option to extract)
# XMP:About = DJI Meta Data
# XMP:ModifyDate = 2023:08:23 11:04:53-05:00
# XMP:CreateDate = 2023:08:23 11:04:53-05:00
# XMP:Make = DJI
# XMP:Model = M3M
# XMP:Format = image/jpg
# XMP:GpsStatus = RTK
# XMP:AltitudeType = RtkAlt
# XMP:GPSLatitude = +40.504323825
# XMP:GPSLongitude = -81.029391176
# XMP:AbsoluteAltitude = +436.264
# XMP:RelativeAltitude = +37.028
# XMP:GimbalRollDegree = +0.00
# XMP:GimbalYawDegree = -115.5
# XMP:GimbalPitchDegree = -52.2
# XMP:FlightRollDegree = +14.50
# XMP:FlightYawDegree = -115.6
# XMP:FlightPitchDegree = -8.0
# XMP:FlightXSpeed = -1.3
# XMP:FlightYSpeed = -4.1
# XMP:FlightZSpeed = -0.5
# XMP:CamReverse = 0
# XMP:GimbalReverse = 0
# XMP:SelfData =
# XMP:RtkFlag = 50
# XMP:RtkStdLon = 0.00927
# XMP:RtkStdLat = 0.01162
# XMP:RtkStdHgt = 0.022
# XMP:RtkDiffAge = 1.4
# XMP:SurveyingMode = 1
# XMP:DewarpFlag = 0
# XMP:DewarpData = 2022-06-08;3713.290000000000,3713.290000000000,7.020000000000,-8.720000000000,-0.112575240000,0.014874430000,-0.000085720000,0.000000100000,-0.027064110000
# XMP:CalibratedFocalLength = 3725.151611
# XMP:CalibratedOpticalCenterX = 2640.0
# XMP:CalibratedOpticalCenterY = 1978.0
# XMP:UTCAtExposure = 2023:08:23 16:05:09.173280
# XMP:ShutterType = Mechanical
# XMP:ShutterCount = 49080
# XMP:CameraSerialNumber = 493OKC18AA004X
# XMP:DroneModel = M3M
# XMP:DroneSerialNumber = 1581F5FKD231300C1FFQ
# XMP:CaptureUUID = 213958a895db4f26a84491a8b41b37a7
# XMP:Version = 7.0
# XMP:HasSettings = False
# XMP:HasCrop = False
# XMP:AlreadyApplied = False
# XMP:RigName = M3M
# XMP:RigCameraIndex = 5
# MPF:MPFVersion = 0100
# MPF:NumberOfImages = 2
# MPF:MPImageFlags = 8
# MPF:MPImageFormat = 0
# MPF:MPImageType = 65537
# MPF:MPImageLength = 1080937
# MPF:MPImageStart = 9261056
# MPF:DependentImage1EntryNumber = 0
# MPF:DependentImage2EntryNumber = 0
# MPF:ImageUIDList = (Binary data 66 bytes, use -b option to extract)
# MPF:TotalFrames = 1
# MPF:PreviewImage = (Binary data 1080937 bytes, use -b option to extract)
# APP7:AEDebugInfo = (Binary data 8192 bytes, use -b option to extract)
# APP7:AEHistogramInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:AELocalHistogram = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewHistogramInfo = (Binary data 2048 bytes, use -b option to extract)
# APP7:AELiveViewLocalHistogram = (Binary data 10000 bytes, use -b option to extract)
# APP7:AWBDebugInfo = (Binary data 10240 bytes, use -b option to extract)
# APP7:AFDebugInfo = (Binary data 1024 bytes, use -b option to extract)
# APP7:Histogram = (Binary data 1024 bytes, use -b option to extract)
# APP7:ADJDebugInfo = (Binary data 4096 bytes, use -b option to extract)
# APP7:SensorID = 493OKC18AA004X
# APP7:HyperlapsDebugInfo = (Binary data 8 bytes, use -b option to extract)
# APP7:Scap_Info = (Binary data 8192 bytes, use -b option to extract)
# APP7:Sisr_Info = (Binary data 4096 bytes, use -b option to extract)
# JFIF:JFIFVersion = 1 2
# JFIF:ResolutionUnit = 0
# JFIF:XResolution = 1
# JFIF:YResolution = 1
# Composite:Aperture = 2.8
# Composite:ImageSize = 5280 3956
# Composite:Megapixels = 20.88768
# Composite:ScaleFactor35efl = 1.95280716029292
# Composite:ShutterSpeed = 0.001
# Composite:GPSAltitude = 436.264
# Composite:GPSLatitude = 40.5043238055556
# Composite:GPSLongitude = -81.0293911666667
# Composite:CircleOfConfusion = 0.0153861892970321
# Composite:FOV = 73.7398575770812
# Composite:FocalLength35efl = 24
# Composite:GPSPosition = 40.5043238055556 -81.0293911666667
# Composite:HyperfocalDistance = 3.50602221168415
# Composite:LightValue = 11.6147098441152
